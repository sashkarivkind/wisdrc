# %%
import os
import sys
import numpy as np
sys.path.insert(0, "/home/bnapp/arivkindNet/wisdrc/")
from parse_commandline import parse_commandline
from utils.imagenet_dataset import get_dataset
from utils.unprocess import *
from utils.image_utils import *
from utils.image_processing import rescale
from utils.split_keras_model import split_model

import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
import pickle as pkl

# %%
#define function to calculate equal-frequency bins 
#taken from: https://www.statology.org/equal-frequency-binning-python/
def equal_freq_bins(x, nbin):
    nlen = len(x)
    return np.interp(np.linspace(0, nlen, nbin + 1),
                     np.arange(nlen),
                     np.sort(x))

def equal_freq_bins_for_batch(feature_map,nbins):
    bin_edges = []
    for feature in feature_map.transpose([3,0,1,2]):
            bin_edges.append(
                equal_freq_bins(np.reshape(feature,[-1]),nbins)
            )
    bin_edges = np.array(bin_edges)
    return bin_edges

def init_bins(n_features, bin_edges):
    """
    TODO: Vectorize.
    See sec. 3.1 in https://arxiv.org/abs/1806.06988 for details on the soft binning procedure.
    """
    # Init bins using super class
#     super(SoftBinStats, self).init_bins()

    # Define W + b for soft binning
    inner_edges = bin_edges[:, 1:-1]           # soft binning method using n "inner" edges for n+1 intervals
    n_edges = inner_edges.shape[1]
#         dev = self.bin_edges.device
    W = []
    b = []
    for f in range(n_features):
        w_ = tf.reshape(tf.linspace(1, n_edges + 1, n_edges + 1), [1, -1])
        b_ = tf.math.cumsum(tf.concat([tf.zeros([1]), -inner_edges[f]], 0), 0)
        W.append(w_)
        b.append(b_)
    W = tf.reshape(tf.stack(W),(n_features, 1, n_edges + 1))  # reshape for matmul later
    b = tf.reshape(tf.stack(b),(n_features, 1, n_edges + 1))  # reshape for matmul later
    return W,b

def generate_random_couplings(n,k,discard_diagonal=False):
    M=np.random.uniform(size=(n,n))
    if discard_diagonal:
        raise NotImplemented
    return np.argwhere(M<k/(n**2))

def mesh_sum(a,b,axis=-1):
    #take two tensors of the same size
    #let the last dimensio of tensor a be (a1,a2,a3,a4)
    #and of tensor b (b1,b2,b3,b4)
    #returns:
    #a1+b1,... a4+b1, 
    #a2+b2 ... a4+b2
    #... 
    #a4+b1  ... a4+b4
    if axis != -1:
        raise NotImplemented
        
    a_shape = tf.shape(a)
    a_tile_times = tf.concat([a_shape[:-1]*0+1,a_shape[-1:]],axis=0)
    a = tf.tile(a,a_tile_times)

    b_shape = tf.shape(b)
    b_tile_times = tf.concat([b_shape*0+1,b_shape[-1:]],axis=0)
    b_target_shape = tf.concat([b_shape[:-1],[-1]],axis=0)
    b = tf.tile(b[...,tf.newaxis],b_tile_times)
    b = tf.reshape(b,b_target_shape)
    
    return a+b



def get_soft_batch_counts(x, n_features, bin_edges, norm_inputs=False, tau=0.1, norm_output=True):
    """ See Neural Decision Forests paper for details on the soft binning procedure. """
    # Conv: [B, H, W, C] --> [C, BxHxW], FC: [B, C] --> [C, B]
    W,b = init_bins(n_features, bin_edges)
    
    x = tf.transpose(x,[3,0,1,2])
    x = tf.reshape(x,[n_features,-1])
    if norm_inputs:
        raise NotImplemented
#         x = norm_inputs(x)
        
    x = tf.reshape(x,(n_features, -1, 1))         # reshape for make-shift batch outer prod via matmul

    # Calculate "logits" per sample via batch outer-product.
    # x:[n_features, n_samples, 1] x W:[n_features, 1, n_bins] = [n_features, n_samples, n_bins]
#     z = tf.matmul(x, W) + b
    z = tf.matmul(x, tf.cast(W,dtype=tf.float32)) + b

    # Calculate soft allocations per sample ("soft" --> sum to 1)
    sft_cs = tf.nn.softmax(z / tau, axis=2)  # [n_features, n_samples, n_bins]

    # Sum over samples to get total soft counts ("soft" --> real number)
    total_sft_cs = tf.reduce_sum(sft_cs,axis=1)

    if norm_output:
        total_sft_cs = total_sft_cs / tf.reduce_sum(total_sft_cs,axis=1,keepdims=True )
        
    return total_sft_cs

def get_soft_batch_counts_sparse2D(x, n_features, bin_edges, couplings=[], norm_inputs=False, tau=0.1, norm_output=True):
    """ TODO: REFACTOR, very similar to the 1D binning. maybe turn to class with inherence? """
    # Conv: [B, H, W, C] --> [C, BxHxW], FC: [B, C] --> [C, B]
    W,b = init_bins(n_features, bin_edges)
    
    x = tf.transpose(x,[3,0,1,2])
    x = tf.reshape(x,[n_features,-1])
    if norm_inputs:
        raise NotImplemented
        
    x = tf.reshape(x,(n_features, -1, 1))         # reshape for make-shift batch outer prod via matmul

    # Calculate "logits" per sample via batch outer-product.
    # x:[n_features, n_samples, 1] x W:[n_features, 1, n_bins] = [n_features, n_samples, n_bins]
#     z = tf.matmul(x, W) + b
    z = tf.matmul(x, tf.cast(W,dtype=tf.float32)) + b
    
    z_couplings = []
    for couple in couplings: 
        z_couplings.append(mesh_sum(z[couple[0],...],z[couple[1],...]))
    
    z_couplings = tf.stack(z_couplings,axis=0)
    # Calculate soft allocations per sample ("soft" --> sum to 1)
    sft_cs = tf.nn.softmax(z_couplings / tau, axis=2)  # [n_features, n_samples, n_bins]

    
    # Sum over samples to get total soft counts ("soft" --> real number)
    total_sft_cs = tf.reduce_sum(sft_cs,axis=1)

    if norm_output:
        total_sft_cs = total_sft_cs / tf.reduce_sum(total_sft_cs,axis=1,keepdims=True )
        
    return total_sft_cs

def keras_loss_for_soft_binning(ref_feature_hist,
                                n_features,
                                bin_edges,
                                couplings=[], 
                                tau=0.1,
                                loss_type='SKLD',
                                mode='1D'):
    kl = tf.keras.losses.KLDivergence()
    def loss_fun(y_true,y_pred):
        #here y_true is a sham input. the reference distribution is fixed for all batches
        if mode=='1D':
            soft_feature_hist=get_soft_batch_counts(y_pred, 
                           n_features, 
                           bin_edges,
                           norm_inputs=False,
                          tau=tau)
        elif mode=='sparse2D':
            soft_feature_hist=get_soft_batch_counts_sparse2D(y_pred, 
                           n_features, 
                           bin_edges,
                            couplings = couplings,
                           norm_inputs=False,
                          tau=tau)
        else:
            raise NotImplementedError
                    
        if loss_type == 'SKLD':
            loss = 0.5*(kl(soft_feature_hist,ref_feature_hist) + kl(ref_feature_hist,soft_feature_hist))
        else:
            raise NotImplementedError
        return loss
    return loss_fun

# %%
def feature_histogram(feature_map,bin_range=[0,10],nbins=10):
    feature_hist = []
    feature_map_tf = tf.constant(feature_map) 
    for feature in feature_map.transpose([3,0,1,2]):
        hist = tf.histogram_fixed_width(tf.reshape(feature,[-1]),bin_range,nbins=nbins)
        hist = hist/tf.reduce_sum(hist)
        feature_hist.append(tf.cast(hist,dtype=tf.float32))
    return feature_hist

# %%
parser = parse_commandline(return_parser=True)
config = parser.parse_args([])
config = vars(config)
parameters = config

# %%
batch_size = 64

# %%
teacher = tf.keras.applications.resnet.ResNet50(input_shape=(224, 224, 3),
                                                      include_top=True,
                                                      weights='imagenet')
split_after_layer = 'pool1_pool'
# Out:
# 2023-04-17 06:00:18.028211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1917] Ignoring visible gpu device (device: 1, name: NVIDIA GeForce GT 730, pci bus id: 0000:65:00.0, compute capability: 3.5) with core count: 2. The minimum required count is 8. You can adjust this requirement with the env var TF_MIN_GPU_MULTIPROCESSOR_COUNT.
# 2023-04-17 06:00:18.458766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1412 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:17:00.0, compute capability: 6.1

# %%
teacher.compile(loss="categorical_crossentropy",
                metrics=["categorical_accuracy", "top_k_categorical_accuracy"],
                )
fe_model, be_model = split_model(teacher, split_after_layer)

# %%
val_generator_baseline = get_dataset(parameters['dataset_dir'], 'validation', batch_size, central_squeeze_and_pad_factor=-1, preprocessing=parameters['preprocessing'])

# %%
for ii,batch in enumerate(val_generator_baseline):
    feature_map = fe_model.predict(batch[0])
    if ii>0:
        break
# Out:
# 2023-04-17 06:01:08.719062: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-04-17 06:01:19.340143: I tensorflow/stream_executor/cuda/cuda_dnn.cc:381] Loaded cuDNN version 8300

# %%
for ff in range(64):
    plt.figure()
    _ = plt.hist(feature_map[:,:,:,ff].reshape([-1]),bins=100)
    plt.title('feature #.{}'.format(ff))
# Out:
# /tmp/ipykernel_16289/2031923291.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
n_features = 64
n_bins = 10
n_bins_2D = 3
binning_noise = 1e-5 #currently not in use. consider using it to avoid degenerated bins at zero

# %%
bin_edges =  equal_freq_bins_for_batch(feature_map
                                       ,n_bins)
bin_edges_2D =  equal_freq_bins_for_batch(feature_map,
                                          n_bins_2D)

# %%
bin_edges
# Out:
# array([[0.00000000e+00, 1.36070955e+00, 1.59126616e+00, 1.78584337e+00,
#         1.96666875e+00, 2.14595246e+00, 2.44703650e+00, 2.86326599e+00,
#         3.47883024e+00, 4.58378315e+00, 2.00359764e+01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.23760426e-01, 9.15446091e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.31023103e-01, 1.68096852e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         3.67034227e-01, 1.22227964e+00, 1.17656097e+01],
#        [0.00000000e+00, 1.23656359e+00, 1.35945184e+00, 1.45037005e+00,
#         1.53439689e+00, 1.65040565e+00, 1.81542883e+00, 2.06530523e+00,
#         2.48382664e+00, 3.36883235e+00, 2.36114578e+01],
#        [0.00000000e+00, 1.10422339e+00, 1.75945814e+00, 2.02032094e+00,
#         2.22620773e+00, 2.40299654e+00, 2.56667447e+00, 2.72948675e+00,
#         2.89189334e+00, 3.25581074e+00, 1.41924314e+01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 3.98112828e-01, 2.19101334e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.16299623e-01, 5.94990921e-01, 9.29151869e-01,
#         1.25549285e+00, 1.89461267e+00, 8.26207638e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         4
+01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.61948258e-01, 2.29110694e+00],
#        [5.28039634e-01, 1.76572008e+00, 1.86059701e+00, 1.96840320e+00,
#         2.11453686e+00, 2.30671644e+00, 2.58615136e+00, 2.98013139e+00,
#         3.59244251e+00, 4.70073137e+00, 2.45434570e+01],
#        [0.00000000e+00, 5.75168419e-01, 7.68543541e-01, 9.20514631e-01,
#         1.05236411e+00, 1.20497024e+00, 1.47225933e+00, 1.87768538e+00,
#         2.53908129e+00, 3.78858004e+00, 1.52003050e+01],
#        [0.00000000e+00, 2.20597577e+00, 2.27852297e+00, 2.36791134e+00,
#         2.50135646e+00, 2.69785810e+00, 2.98976536e+00, 3.42082858e+00,
#         4.09272346e+00, 5.32828236e+00, 2.72926140e+01],
#        [1.29126477e+00, 2.13728585e+00, 2.26926475e+00, 2.40775304e+00,
#         2.56907544e+00, 2.78087711e+00, 3.06742454e+00, 3.46551833e+00,
#         4.05772829e+00, 5.10833788e+00, 2.28565426e+01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.15256551e-01, 5.63619554e-01, 3.36797166e+00],
#        [0.00000000e+00, 1.28661215e-01, 6.39609516e-01, 9.32027102e-01,
#         1.11276302e+00, 1.24497950e+00, 1.40522053e+00, 1.58092511e+00,
#         1.76790154e+00, 2.30250697e+00, 7.43007183e+00],
#        [0.00000000e+00, 2.09085178e+00, 2.15348196e+00, 2.24910140e+00,
#         2.39757090e+00, 2.61148643e+00, 2.91521502e+00, 3.34666371e+00,
#         4.00490856e+00, 5.25652504e+00, 2.26411514e+01]])

# %%
soft_bins=get_soft_batch_counts(feature_map[:64], 
                           n_features, 
                           bin_edges,
                           norm_inputs=False,
                          tau=0.1)
# Out:
# 2023-04-17 06:02:19.377806: W tensorflow/core/common_runtime/bfc_allocator.cc:463] Allocator (GPU_0_bfc) ran out of memory trying to allocate 490.00MiB (rounded to 513802240)requested by op Softmax
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-04-17 06:02:19.377991: I tensorflow/core/common_runtime/bfc_allocator.cc:1013] BFCAllocator dump for GPU_0_bfc
# 2023-04-17 06:02:19.378055: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (256): 	Total Chunks: 116, Chunks in use: 116. 29.0KiB allocated for chunks. 29.0KiB in use in bin. 16.5KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378097: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (512): 	Total Chunks: 81, Chunks in use: 80. 40.5KiB allocated for chunks. 40.0KiB in use in bin. 40.0KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378136: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (1024): 	Total Chunks: 162, Chunks in use: 161. 164.8KiB allocated for chunks. 163.2KiB in use in bin. 161.0KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378175: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (2048): 	Total Chunks: 112, Chunks in use: 111. 227.5KiB allocated for chunks. 225.2KiB in use in bin. 222.5KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378224: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (4096): 	Total Chunks: 73, Chunks in use: 73. 304.0KiB allocated for chunks. 304.0KiB in use in bin. 292.8KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378268: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (8192): 	Total Chunks: 40, Chunks in use: 40. 332.5KiB allocated for chunks. 332.5KiB in use in bin. 320.0KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378304: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (16384): 	Total Chunks: 3, Chunks in use: 2. 61.8KiB allocated for chunks. 32.0KiB in use in bin. 32.0KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378337: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-17 06:02:19.378373: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (65536): 	Total Chunks: 13, Chunks in use: 13. 925.8KiB allocated for chunks. 925.8KiB in use in bin. 804.8KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378411: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (131072): 	Total Chunks: 7, Chunks in use: 6. 1.08MiB allocated for chunks. 908.0KiB in use in bin. 832.0KiB client-requested in use in bin.
# 2023-04-17 06:02:19.378452: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (262144): 	Total Chunks: 18, Chunks in use: 16. 4.95MiB allocated for chunks. 4.31MiB in use in bin. 3.78MiB client-requested in use in bin.
# 2023-04-17 06:02:19.378487: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (524288): 	Total Chunks: 10, Chunks in use: 10. 6.80MiB allocated for chunks. 6.80MiB in use in bin. 5.38MiB client-requested in use in bin.
# 2023-04-17 06:02:19.378524: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (1048576): 	Total Chunks: 26, Chunks in use: 24. 29.25MiB allocated for chunks. 27.00MiB in use in bin. 23.12MiB client-requested in use in bin.
# 2023-04-17 06:02:19.378560: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (2097152): 	Total Chunks: 16, Chunks in use: 14. 40.50MiB allocated for chunks. 36.25MiB in use in bin. 30.50MiB client-requested in use in bin.
# 2023-04-17 06:02:19.378597: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (4194304): 	Total Chunks: 17, Chunks in use: 14. 92.06MiB allocated for chunks. 75.25MiB in use in bin. 60.12MiB client-requested in use in bin.
# 2023-04-17 06:02:19.378633: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (8388608): 	Total Chunks: 9, Chunks in use: 8. 90.19MiB allocated for chunks. 82.00MiB in use in bin. 70.00MiB client-requested in use in bin.
# 2023-04-17 06:02:19.378667: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-17 06:02:19.378721: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (33554432): 	Total Chunks: 2, Chunks in use: 1. 98.00MiB allocated for chunks. 49.00MiB in use in bin. 49.00MiB client-requested in use in bin.
# 2023-04-17 06:02:19.378783: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-17 06:02:19.378814: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-17 06:02:19.378840: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (268435456): 	Total Chunks: 2, Chunks in use: 2. 1.02GiB allocated for chunks. 1.02GiB in use in bin. 980.00MiB client-requested in use in bin.
# 2023-04-17 06:02:19.378863: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] Bin for 490.00MiB was 256.00MiB, Chunk State:
# 2023-04-17 06:02:19.378881: I tensorflow/core/common_runtime/bfc_allocator.cc:1049] Next region of size 1480589312
# 2023-04-17 06:02:19.378918: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000000 of size 1280 next 1
# 2023-04-17 06:02:19.378935: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000500 of size 256 next 2
# 2023-04-17 06:02:19.378951: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000600 of size 256 next 3
# 2023-04-17 06:02:19.378966: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000700 of size 256 next 4
# 2023-04-17 06:02:19.378981: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000800 of size 256 next 5
# 2023-04-17 06:02:19.378996: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000900 of size 256 next 8
# 2023-04-17 06:02:19.379024: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000a00 of size 256 next 9
# 2023-04-17 06:02:19.379042: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000b00 of size 256 next 10
# 2023-04-17 06:02:19.379057: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000c00 of size 256 next 11
# 2023-04-17 06:02:19.379073: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000d00 of size 256 next 12
# 2023-04-17 06:02:19.379088: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000e00 of size 256 next 13
# 2023-04-17 06:02:19.379103: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1ea000f00 of size 256 next 14
# 2023-04-17 06:02:19.379118: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fb1
I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 2 Chunks of size 2621440 totalling 5.00MiB
# 2023-04-17 06:02:19.390672: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 2883584 totalling 2.75MiB
# 2023-04-17 06:02:19.390689: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 3145728 totalling 3.00MiB
# 2023-04-17 06:02:19.390706: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 3 Chunks of size 3670016 totalling 10.50MiB
# 2023-04-17 06:02:19.390723: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 7 Chunks of size 4194304 totalling 28.00MiB
# 2023-04-17 06:02:19.390746: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 2 Chunks of size 5242880 totalling 10.00MiB
# 2023-04-17 06:02:19.390763: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 6291456 totalling 6.00MiB
# 2023-04-17 06:02:19.390799: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 4 Chunks of size 8192000 totalling 31.25MiB
# 2023-04-17 06:02:19.390816: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 5 Chunks of size 9437184 totalling 45.00MiB
# 2023-04-17 06:02:19.390832: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 10485760 totalling 10.00MiB
# 2023-04-17 06:02:19.390849: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 12582912 totalling 12.00MiB
# 2023-04-17 06:02:19.390865: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 15728640 totalling 15.00MiB
# 2023-04-17 06:02:19.390882: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 51380224 totalling 49.00MiB
# 2023-04-17 06:02:19.390898: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 513802240 totalling 490.00MiB
# 2023-04-17 06:02:19.390916: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 584203776 totalling 557.14MiB
# 2023-04-17 06:02:19.390932: I tensorflow/core/common_runtime/bfc_allocator.cc:1081] Sum Total of in-use chunks: 1.30GiB
# 2023-04-17 06:02:19.390948: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] total_region_allocated_bytes_: 1480589312 memory_limit_: 1480589312 available bytes: 0 curr_region_allocation_bytes_: 2961178624
# 2023-04-17 06:02:19.390971: I tensorflow/core/common_runtime/bfc_allocator.cc:1089] Stats:
# Limit:                      1480589312
# InUse:                      1395277056
# MaxInUse:                   1395277056
# NumAllocs:                        3733
# MaxAllocSize:                584203776
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-04-17 06:02:19.391040: W tensorflow/core/common_runtime/bfc_allocator.cc:474] *******************___**************************************************************************xxxx
# 2023-04-17 06:02:19.391102: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at softmax_op_gpu.cu.cc:210 : Resource exhausted: OOM when allocating tensor with shape[64,200704,10] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_16289/3977067421.py in <module>
# ----> 1 soft_bins=get_soft_batch_counts(feature_map[:64],
#       2                            n_features,
#       3                            bin_edges,
#       4                            norm_inputs=False,
#       5                           tau=0.1)
#
# /tmp/ipykernel_16289/1324563903.py in get_soft_batch_counts(x, n_features, bin_edges, norm_inputs, tau, norm_output)
#      90
#      91     # Calculate soft allocations per sample ("soft" --> sum to 1)
# ---> 92     sft_cs = tf.nn.softmax(z / tau, axis=2)  # [n_features, n_samples, n_bins]
#      93
#      94     # Sum over samples to get total soft counts ("soft" --> real number)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py in softmax_v2(logits, axis, name)
#    3818   if axis is None:
#    3819     axis = -1
# -> 3820   return _wrap_2d_function(logits, gen_nn_ops.softmax, axis, name)
#    3821
#    3822
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py in _wrap_2d_function(inputs, compute_op, dim, name)
#    3737
#    3738   if is_last_dim:
# -> 3739     return compute_op(inputs, name=name)
#    3740
#    3741   dim_val = dim
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py in softmax(logits, name)
#   10862       return _result
#   10863     except _core._NotOkStatusException as e:
# > 10864       _ops.raise_from_not_ok_status(e, name)
#   10865     except _core._FallbackException:
#   10866       pass
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6939   message = e.message + (" name: " + name if name is not None else "")
#    6940   # pylint: disable=protected-access
# -> 6941   six.raise_from(core._status_to_exception(e.code, message), None)
#    6942   # pylint: enable=protected-access
#    6943
#
# /usr/local/lib/python3.8/dist-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[64,200704,10] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Softmax]

# %%
couplings = generate_random_couplings(n_features,
                                      2*n_features) #two links per feature

# %%
couplings

# %%
soft_bins_2D=get_soft_batch_counts_sparse2D(feature_map[:64], 
                           n_features, 
                           bin_edges_2D,
                        couplings=couplings,
                           norm_inputs=False,
                          tau=0.1)

# %%
import gc

# %%
gc.collect()

# %%
soft_bins_2D_debug=get_soft_batch_counts_sparse2D(feature_map[:64], 
                           n_features, 
                           bin_edges_2D,
                        couplings=[[5,13]],
                           norm_inputs=False,
                          tau=0.1)

# %%
for ii,uu in enumerate(soft_bins_2D.numpy()):
    print(ii,uu.reshape([3,3]))
    print(ii,uu.sum())

# %%
soft_bins_2D_debug.numpy().reshape([3,3])

# %%
soft_bins_2D_debug.numpy().reshape([3,3]).sum(axis=0),soft_bins_2D_debug.numpy().reshape([3,3]).sum(axis=1)

# %%
reference_feature_stats = {'stats': soft_bins.numpy(), 'bin_edges': bin_edges, 
                           'stats_2D': soft_bins_2D.numpy(), 'bin_edges_2D': bin_edges_2D,
                           'couplings': couplings}

# %%
# with open('../data_files/reference_feature_stats_resnet50_eq10bins_3x3bins_256img_v1.pkl','wb') as f:
#     pkl.dump(reference_feature_stats,f) #this one was actually 64 images...

# %%
# with open('../data_files/reference_feature_stats_resnet50_eq10bins_3x3bins_256img_v1.pkl','rb') as f:
#     reference_feature_stats = pkl.load(f)

# %%
train_generator_baseline = get_dataset(parameters['dataset_dir'], 'train', batch_size, preprocessing=parameters['preprocessing'])

# %%
for ii,batch in enumerate(train_generator_baseline):
    feature_map = fe_model.predict(batch[0])
    if ii>0:
        break

# %%
bin_edges =  equal_freq_bins_for_batch(feature_map
                                       ,n_bins)
bin_edges_2D =  equal_freq_bins_for_batch(feature_map,
                                          n_bins_2D)

# %%
train_generator_64 = get_dataset(parameters['dataset_dir'], 'train', 64, preprocessing=parameters['preprocessing'])

# %%
loss1D_rec = []
loss2D_rec = []
accum_feature_stats = 0
accum_feature_stats_2D = 0
max_iter = 30
for ii,batch in enumerate(train_generator_64):
    feature_map = fe_model.predict(batch[0])
    if ii>max_iter:
        break
    print(ii)
    feature_stats = get_soft_batch_counts(feature_map, 
                           n_features, 
                           bin_edges,
                           norm_inputs=False,
                          tau=0.1)
    feature_stats_2D = get_soft_batch_counts_sparse2D(feature_map, 
                           n_features, 
                           bin_edges_2D,
                        couplings=couplings,
                           norm_inputs=False,
                          tau=0.1)
    accum_feature_stats = 1./(ii+1)*(accum_feature_stats *ii + feature_stats)
    accum_feature_stats_2D = 1./(ii+1)*(accum_feature_stats_2D *ii + feature_stats_2D)
    
    if ii>0:
        loss1D_rec.append(loss1D(999,feature_map))
        loss2D_rec.append(loss2D(999,feature_map))
    
    loss1D = keras_loss_for_soft_binning(np.array(accum_feature_stats),
                                       n_features,
                                       bin_edges,
                                       tau=0.1,
                                       loss_type='SKLD')
    loss2D = keras_loss_for_soft_binning(np.array(accum_feature_stats_2D),
                                       n_features,
                                       bin_edges_2D,
                                        couplings=couplings,
                                       tau=0.1,
                                       loss_type='SKLD',
                                       mode='sparse2D')
    gc.collect()

# %%
plt.plot([uu.numpy() for uu in loss1D_rec],'*')
plt.plot([uu.numpy() for uu in loss2D_rec],'x')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16289/1440331151.py in <module>
# ----> 1 plt.plot([uu.numpy() for uu in loss1D_rec],'*')
#       2 plt.plot([uu.numpy() for uu in loss2D_rec],'x')
#
# NameError: name 'loss1D_rec' is not defined

# %%
accum_feature_stats_run1 =accum_feature_stats.numpy()
accum_feature_stats_2D_run1 =accum_feature_stats_2D.numpy()

# %%
kl = tf.keras.losses.KLDivergence()
SKLD = 0.5*(kl(accum_feature_stats_run1,accum_feature_stats) + kl(accum_feature_stats,accum_feature_stats_run1))

# %%
print(SKLD)

# %%
0.5*(kl(accum_feature_stats,accum_feature_stats) + kl(accum_feature_stats,accum_feature_stats))

# %%
train_generator_4 = get_dataset(parameters['dataset_dir'], 'train', 4, preprocessing=parameters['preprocessing'])

# %%
loss1D_rec = []
loss2D_rec = []
accum_feature_stats = 0
accum_feature_stats_2D = 0
max_iter = 30
for ii,batch in enumerate(train_generator_4):
    feature_map = fe_model.predict(batch[0])
    if ii>max_iter:
        break
    print(ii)
    feature_stats = get_soft_batch_counts(feature_map, 
                           n_features, 
                           bin_edges,
                           norm_inputs=False,
                          tau=0.1)
    feature_stats_2D = get_soft_batch_counts_sparse2D(feature_map, 
                           n_features, 
                           bin_edges_2D,
                        couplings=couplings,
                           norm_inputs=False,
                          tau=0.1)
    accum_feature_stats = 1./(ii+1)*(accum_feature_stats *ii + feature_stats)
    accum_feature_stats_2D = 1./(ii+1)*(accum_feature_stats_2D *ii + feature_stats_2D)
    
    if ii>0:
        loss1D_rec.append(loss1D(999,feature_map))
        loss2D_rec.append(loss2D(999,feature_map))
    
    loss1D = keras_loss_for_soft_binning(np.array(accum_feature_stats),
                                       n_features,
                                       bin_edges,
                                       tau=0.1,
                                       loss_type='SKLD')
    loss2D = keras_loss_for_soft_binning(np.array(accum_feature_stats_2D),
                                       n_features,
                                       bin_edges_2D,
                                        couplings=couplings,
                                       tau=0.1,
                                       loss_type='SKLD',
                                       mode='sparse2D')
    gc.collect()

# %%
plt.plot([uu.numpy() for uu in loss1D_rec])
plt.plot([uu.numpy() for uu in loss2D_rec])

# %%
len(couplings)

# %%
full_couplings = []
for f1 in range(n_features):
    for f2 in range(f1+1, n_features):
        full_couplings.append([f1,f2])

# %%
len(full_couplings)

# %%
coupling_chunk_len = 64
n_chunks = len(full_couplings)//coupling_chunk_len
if len(full_couplings) % coupling_chunk_len:
    n_chunks += 1
loss1D_rec = []
loss2D_rec = []
accum_feature_stats = 0
accum_feature_stats_2D = 0
max_iter = 30
for ii,batch in enumerate(train_generator_64):
    feature_map = fe_model.predict(batch[0])
    if ii>max_iter:
        break
    print(ii)
    feature_stats = get_soft_batch_counts(feature_map, 
                           n_features, 
                           bin_edges,
                           norm_inputs=False,
                          tau=0.1)
    
    feature_stats_2D = []
    for idx in range(n_chunks):
        feature_stats_2D.append(get_soft_batch_counts_sparse2D(feature_map, 
                               n_features, 
                               bin_edges_2D,
                            couplings=full_couplings[idx*coupling_chunk_len:(idx+1)*coupling_chunk_len],
                               norm_inputs=False,
                              tau=0.1))
    feature_stats_2D = tf.concat(feature_stats_2D, axis=0)  
    
    accum_feature_stats = 1./(ii+1)*(accum_feature_stats *ii + feature_stats)
    accum_feature_stats_2D = 1./(ii+1)*(accum_feature_stats_2D *ii + feature_stats_2D)
    
#     if ii>0:
#         loss1D_rec.append(loss1D(999,feature_map))
#         loss2D_rec.append(loss2D(999,feature_map))
    
#     loss1D = keras_loss_for_soft_binning(np.array(accum_feature_stats),
#                                        n_features,
#                                        bin_edges,
#                                        tau=0.1,
#                                        loss_type='SKLD')
#     loss2D = keras_loss_for_soft_binning(np.array(accum_feature_stats_2D),
#                                        n_features,
#                                        bin_edges_2D,
#                                         couplings=full_couplings,
#                                        tau=0.1,
#                                        loss_type='SKLD',
#                                        mode='sparse2D')
    gc.collect()

# %%
coupling_mat = np.zeros([n_features,n_features])
idx = 0
for f1 in range(n_features):
    for f2 in range(f1+1, n_features):
        coupling_mat[f1,f2] = np.var(accum_feature_stats_2D[idx].numpy())
        idx += 1

# %%
plt.imshow(coupling_mat)

# %%
coupling_vars = np.array([np.var(uu.numpy()) for uu in accum_feature_stats_2D])
_ = plt.hist(coupling_vars,bins=30)

# %%
th = 0.004

# %%
(coupling_vars > th).sum()

# %%
plt.imshow(coupling_mat > th)

# %%
strong_couplings_idx = np.nonzero(coupling_vars > th)[0]

# %%
strong_couplings = [full_couplings[uu] for uu in strong_couplings_idx]

# %%
reference_feature_stats = {'stats': accum_feature_stats.numpy(), 'bin_edges': bin_edges, 
                           'stats_2D': accum_feature_stats_2D.numpy()[strong_couplings_idx], 'bin_edges_2D': bin_edges_2D,
                           'couplings': strong_couplings}

# %%
vv = accum_feature_stats_2D.numpy()[strong_couplings_idx].reshape([-1,3,3])

# %%
for zz in range(100,120):
    plt.figure()
    plt.imshow(vv[zz])

# %%
# with open('../data_files/reference_feature_stats_resnet50_eq10bins_strong3x3bins_1920img_v2.pkl','wb') as f:
#     pkl.dump(reference_feature_stats,f) #this one was actually 64 images...

# %%
# with open('../data_files/reference_feature_stats_resnet50_eq10bins_strong3x3bins_1920img_v1.pkl','rb') as f:
#     reference_feature_stats = pkl.load(f) #this one was actually 64 images...

# %%
strong_couplings_idx=reference_feature_stats['couplings']

# %%
strong_couplings = [full_couplings[uu] for uu in strong_couplings_idx]

# %%
reference_feature_stats['couplings'] = strong_couplings

# %%
teacher.layers[1].name,teacher.layers[2].name,teacher.layers[3].name, teacher.layers[2].weights

# %%
teacher.layers[1].get_config()

# %%
teacher.layers[2].get_config()

# %%
teacher.layers[4].get_config()
